# %%
import sys
import os

sys.path.append(os.path.abspath("C:/Users/jvans/Documents/NOP/Feature_Selection/src"))

# %%
from preprocess import load_data
from adaptive_lasso import AdaptiveLasso

X_train, X_test, y_train, y_test = load_data()

adaptive = AdaptiveLasso(lr=0.001, lam=5, iterations=2000)
adaptive.fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt

plt.plot(adaptive.loss_history)
plt.title("Adaptive LASSO Convergence")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.savefig("convergence.png")
plt.show()

# %%
print(adaptive.beta)
# Out:
# [-0.45475554 -0.         -0.445427    0.80368284 -0.18417883  3.49294539
#  -0.         -0.88299764  0.07723339 -0.44047355 -1.8743504   0.78553323
#  -2.9863011 ]
